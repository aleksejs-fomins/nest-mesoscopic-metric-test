# %%
import sys
import numpy as np
import matplotlib.pyplot as plt

from read_yaro import read_mat_multi
# Read LVM file from command line
mousedict = read_mat_multi("/mnt/hifo_scratch1/Yaro/data_for_TE/mtp")
# Out:
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_18_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_19_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_22_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_23_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_24_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_25_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_06_26_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_07_14_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_1/mtp_1_2015_07_15_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_10_26_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_01_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_02_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_02_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_04_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_07_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_08_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_23_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_24_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_25_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_28_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_29_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_11_30_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_01_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_02_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_05_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_06_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_07_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_08_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_09_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_12_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_14_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_15_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_12/mtp_12_2016_12_16_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_16_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_17_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_18_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_19_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_22_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_23_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_24_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_25_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_29_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_30_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_05_31_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_06_01_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_15/mtp_15_2018_06_04_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_16_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_17_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_19_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_20_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_22_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_23_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_24_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_25_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_29_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_30_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_05_31_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_06_01_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_16/mtp_16_2018_06_04_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_18_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_19_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_22_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_23_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_24_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_25_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_02_26_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_01_a_
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_02_a_
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_03_a_
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_08_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_09_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_11_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_14_b
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_15_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_16_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_17_a
# Reading Yaro data from /mnt/hifo_scratch1/Yaro/data_for_TE/mtp/mtp_7/mtp_7_2016_03_18_a

# %%
# %matplotlib notebook

nTimes = 201
tlst = 50*np.linspace(0, nTimes, nTimes)


# for day_dict in mousedict.values():
#     for data in day_dict.values():
#         print(data['data'].shape)

NTot = 0
nChannels = 12
nTimes = 201
data_mean = np.zeros((nTimes, nChannels))
data_std = np.zeros((nTimes, nChannels))

mousekey = list(mousedict.keys())[0]
for data in mousedict[mousekey].values():
    if data['data'].shape[2] == nChannels:
        NTot += data['data'].shape[0]
        data_mean += np.sum(data['data'], axis=0)

data_mean /= NTot
    
for data in mousedict[mousekey].values():
    if data['data'].shape[2] == nChannels:
        data_std += np.sum((data['data'] - data_mean)**2, axis=0)
    
data_std = np.sqrt(data_std / (NTot - 1))


fig, ax = plt.subplots(figsize=(5,5), tight_layout=True)
for i in range(nChannels):
    ax.plot(tlst, data_mean[:, i], label="channel_"+str(i))
    ax.fill_between(tlst, data_mean[:, i]-data_std[:, i], data_mean[:, i]+data_std[:, i], alpha=0.2)

ax.set_title('Mean activity per channel')
ax.set_ylabel('mean activity')
ax.set_xlabel('time, ms')
ax.legend()
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="499.58333333333337">
